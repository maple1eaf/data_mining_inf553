# %%
import findspark
findspark.init()

# %%
import json
# import os

# %%
from pyspark import SparkConf, SparkContext, StorageLevel
# from pyspark.sql import SparkSession

# %%
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

# %%
train_file = "file:///Users/markduan/duan/USC_course/USC_APDS/INF553/project/data/train_review.json"
test_file = "file:///Users/markduan/duan/USC_course/USC_APDS/INF553/project/data/test_review.json"
model_file = "/Users/markduan/duan/USC_course/USC_APDS/INF553/project/model/als.json"
checkpoint_file = "file:///Users/markduan/duan/USC_course/USC_APDS/INF553/project/dev/checkpoint"

# %%
conf = SparkConf() \
    .setAppName("task") \
    .setMaster("local[*]") \
    .set("spark.driver.memory","4g")
sc = SparkContext(conf=conf)
sc.setLogLevel("ERROR")

# %%
train_data = sc.textFile(train_file) \
    .map(json.loads) \
    .map(lambda x: ((x['user_id'], x['business_id']), [x['stars']])) \
    .reduceByKey(lambda x, y: x + y) \
    .mapValues(lambda vs: max(vs)) \
    .collectAsMap()

# %%
# spark = SparkSession.builder.config(conf=SparkConf()).getOrCreate()

# %%
raw_data = sc.textFile(train_file).map(json.loads).persist(StorageLevel.MEMORY_AND_DISK)

# %%
lonely_user = raw_data.map(lambda x: (x['user_id'], 1)) \
    .reduceByKey(lambda x, y: x + y) \
    .filter(lambda x: x[1] < 1) \
    .map(lambda x: x[0]) \
    .collect()

# %%
lonely_business = raw_data.map(lambda x: (x['business_id'], 1)) \
    .reduceByKey(lambda x, y: x + y) \
    .filter(lambda x: x[1] < 1) \
    .map(lambda x: x[0]) \
    .collect()

# %%
u_table = raw_data.map(lambda x: x['user_id']) \
    .distinct() \
    .collect()

# %%
b_table = raw_data.map(lambda x: x['business_id']) \
    .distinct() \
    .collect()

# %%
u_d = {}
for i in range(len(u_table)):
    k = u_table[i]
    u_d[k] = i
b_d = {}
for i in range(len(b_table)):
    k = b_table[i]
    b_d[k] = i

# %%
def meanList(l):
    return sum(l) / len(l)

# %%
stars_data = raw_data.map(lambda x: ((x['user_id'], x['business_id']), [x['stars']])) \
    .filter(lambda x: x[0][0] not in lonely_user and x[0][1] not in lonely_business) \
    .reduceByKey(lambda x, y: x + y) \
    .map(lambda x: (x[0], meanList(x[1]))) \
    .map(lambda x: (u_d[x[0][0]], b_d[x[0][1]], x[1])) \
    .map(lambda x: Rating(x[0], x[1], x[2])) \
    .persist(StorageLevel.MEMORY_AND_DISK)

# %%
stars_data.collect()
# Out:
# [Rating(user=56400, product=7062, rating=5.0),
#  Rating(user=60017, product=12653, rating=5.0),
#  Rating(user=70635, product=11086, rating=4.0),
#  Rating(user=24744, product=2508, rating=2.0),
#  Rating(user=5, product=2031, rating=5.0),
#  Rating(user=77589, product=3041, rating=1.0),
#  Rating(user=45885, product=11600, rating=5.0),
#  Rating(user=56405, product=10042, rating=2.0),
#  Rating(user=81077, product=9528, rating=5.0),
#  Rating(user=35245, product=7067, rating=1.0),
#  Rating(user=7029, product=10045, rating=5.0),
#  Rating(user=49444, product=7072, rating=3.0),
#  Rating(user=45891, product=6545, rating=5.0),
#  Rating(user=60023, product=12658, rating=3.0),
#  Rating(user=88202, product=6552, rating=3.0),
#  Rating(user=35251, product=969, rating=1.0),
#  Rating(user=10590, product=9539, rating=5.0),
#  Rating(user=56416, product=10052, rating=4.0),
#  Rating(user=1, product=4081, rating=3.0),
#  Rating(user=3469, product=8522, rating=5.0),
#  Rating(user=52926, product=4555, rating=5.0),
#  Rating(user=21155, product=3055, rating=4.0),
#  Rating(user=52927, product=1522, rating=4.0),
#  Rating(user=52929, product=5555, rating=3.0),
#  Rating(user=17652, product=10594, rating=4.0),
#  Rating(user=70657, product=11085, rating=4.0),
#  Rating(user=3477, product=488, rating=4.0),
#  Rating(user=31745, product=10607, rating=4.0),
#  Rating(user=28282, product=8057, rating=4.0),
#  Rating(user=3479, product=4570, rating=5.0),
#  Rating(user=28285, product=7089, rating=5.0),
#  Rating(user=3481, product=12677, rating=1.0),
#  Rating(user=56429, product=4087, rating=4.0),
#  Rating(user=81101, product=7582, rating=5.0),
#  Rating(user=14122, product=4087, rating=1.0),
#  Rating(user=42349, product=9079, rating=5.0),
#  Rating(user=56436, product=2028, rating=5.0),
#  Rating(user=74158, product=9558, rating=4.0),
#  Rating(user=60050, product=2543, rating=4.0),
#  Rating(user=3487, product=1547, rating=3.0),
#  Rating(user=28293, product=998, rating=5.0),
#  Rating(user=67161, product=12652, rating=5.0),
#  Rating(user=49480, product=9072, rating=5.0),
#  Rating(user=31754, product=1549, rating=4.0),
#  Rating(user=35282, product=2065, rating=5.0),
#  Rating(user=67164, product=4587, rating=3.0),
#  Rating(user=88237, product=3538, rating=5.0),
#  Rating(user=74177, product=8552, rating=1.0),
#  Rating(user=38790, product=11632, rating=4.0),
#  Rating(user=88242, product=506, rating=5.0),
#  Rating(user=84732, product=50, rating=2.0),
#  Rating(user=56448, product=5076, rating=5.0),
#  Rating(user=38794, product=5580, rating=5.0),
#  Rating(user=84728, product=11107, rating=4.0),
#  Rating(user=74180, product=12693, rating=5.0),
#  Rating(user=14142, product=1007, rating=5.0),
#  Rating(user=14145, product=11131, rating=3.0),
#  Rating(user=45944, product=7593, rating=5.0),
#  Rating(user=17681, product=10613, rating=1.0),
#  Rating(user=52966, product=7556, rating=4.0),
#  Rating(user=38798, product=11629, rating=1.0),
#  Rating(user=31764, product=12700, rating=2.0),
#  Rating(user=17684, product=12704, rating=5.0),
#  Rating(user=35302, product=7097, rating=5.0),
#  Rating(user=3502, product=3598, rating=5.0),
#  Rating(user=81145, product=7600, rating=1.0),
#  Rating(user=21194, product=1012, rating=4.0),
#  Rating(user=21199, product=7094, rating=4.0),
#  Rating(user=74191, product=1572, rating=5.0),
#  Rating(user=52975, product=3601, rating=4.0),
#  Rating(user=24798, product=9530, rating=3.0),
#  Rating(user=88268, product=10629, rating=4.0),
#  Rating(user=63670, product=7100, rating=4.5),
#  Rating(user=81151, product=8555, rating=1.0),
#  Rating(user=38805, product=1579, rating=1.0),
#  Rating(user=3514, product=11637, rating=2.0),
#  Rating(user=74195, product=10631, rating=1.0),
#  Rating(user=28321, product=7087, rating=4.0),
#  Rating(user=87, product=2045, rating=4.0),
#  Rating(user=24806, product=7607, rating=5.0),
#  Rating(user=31755, product=8577, rating=2.0),
#  Rating(user=67174, product=2547, rating=5.0),
#  Rating(user=52989, product=2505, rating=3.0),
#  Rating(user=56485, product=9090, rating=5.0),
#  Rating(user=70717, product=2085, rating=3.0),
#  Rating(user=67210, product=537, rating=5.0),
#  Rating(user=81156, product=538, rating=3.5),
#  Rating(user=14173, product=6099, rating=4.0),
#  Rating(user=21217, product=10091, rating=3.0),
#  Rating(user=67212, product=9596, rating=3.0),
#  Rating(user=88280, product=540, rating=5.0),
#  Rating(user=67216, product=541, rating=4.0),
#  Rating(user=17708, product=1584, rating=5.0),
#  Rating(user=49523, product=3102, rating=5.0),
#  Rating(user=3531, product=544, rating=3.0),
#  Rating(user=77675, product=3104, rating=5.0),
#  Rating(user=17716, product=7555, rating=4.0),
#  Rating(user=14178, product=1021, rating=4.5),
#  Rating(user=28335, product=7068, rating=1.0),
#  Rating(user=70721, product=5062, rating=5.0),
#  Rating(user=67227, product=4614, rating=5.0),
#  Rating(user=3537, product=6558, rating=5.0),
#  Rating(user=74169, product=6611, rating=5.0),
#  Rating(user=14183, product=6106, rating=1.0),
#  Rating(user=31816, product=6599, rating=5.0),
#  Rating(user=38831, product=12728, rating=4.0),
#  Rating(user=35350, product=11161, rating=3.0),
#  Rating(user=49533, product=5064, rating=5.0),
#  Rating(user=35351, product=6112, rating=4.0),
#  Rating(user=77690, product=8112, rating=4.0),
#  Rating(user=38836, product=5603, rating=2.0),
#  Rating(user=7119, product=5115, rating=5.0),
#  Rating(user=106, product=4136, rating=1.0),
#  Rating(user=70634, product=4100, rating=3.5),
#  Rating(user=45986, product=11637, rating=3.0),
#  Rating(user=84786, product=3118, rating=2.0),
#  Rating(user=84787, product=11167, rating=3.0),
#  Rating(user=84788, product=2100, rating=5.0),
#  Rating(user=53010, product=2593, rating=5.0),
#  Rating(user=70744, product=11093, rating=3.0),
#  Rating(user=14193, product=995, rating=1.0),
#  Rating(user=35367, product=4108, rating=5.0),
#  Rating(user=81188, product=3638, rating=5.0),
#  Rating(user=74244, product=3639, rating=5.0),
#  Rating(user=70715, product=9074, rating=4.0),
#  Rating(user=3564, product=6628, rating=5.0),
#  Rating(user=88318, product=11673, rating=2.0),
#  Rating(user=60047, product=7562, rating=4.0),
#  Rating(user=118, product=9075, rating=5.0),
#  Rating(user=53018, product=2563, rating=4.0),
#  Rating(user=56527, product=1055, rating=2.0),
#  Rating(user=3570, product=2601, rating=5.0),
#  Rating(user=31845, product=12753, rating=3.5),
#  Rating(user=14211, product=43, rating=5.0),
#  Rating(user=56530, product=992, rating=5.0),
#  Rating(user=121, product=978, rating=3.0),
#  Rating(user=74256, product=4636, rating=2.0),
#  Rating(user=14218, product=5126, rating=1.0),
#  Rating(user=70765, product=11176, rating=4.0),
#  Rating(user=38864, product=9621, rating=5.0),
#  Rating(user=53026, product=2527, rating=1.0),
#  Rating(user=60160, product=3639, rating=4.0),
#  Rating(user=74259, product=562, rating=5.0),
#  Rating(user=21269, product=8071, rating=5.0),
#  Rating(user=21271, product=77, rating=5.0),
#  Rating(user=3586, product=3557, rating=3.0),
#  Rating(user=60162, product=10670, rating=5.0),
#  Rating(user=35387, product=1062, rating=5.0),
#  Rating(user=31852, product=5613, rating=4.0),
#  Rating(user=74266, product=11688, rating=3.0),
#  Rating(user=60164, product=8618, rating=4.0),
#  Rating(user=67286, product=8619, rating=5.0),
#  Rating(user=74270, product=2612, rating=1.0),
#  Rating(user=10716, product=7599, rating=1.0),
#  Rating(user=88339, product=11602, rating=3.0),
#  Rating(user=88345, product=523, rating=5.0),
#  Rating(user=45989, product=1558, rating=3.0),
#  Rating(user=88316, product=6612, rating=1.0),
#  Rating(user=49577, product=1071, rating=5.0),
#  Rating(user=63733, product=5106, rating=5.0),
#  Rating(user=53041, product=11693, rating=4.0),
#  Rating(user=10679, product=1618, rating=4.0),
#  Rating(user=60179, product=3656, rating=5.0),
#  Rating(user=56558, product=115, rating=5.0),
#  Rating(user=14239, product=11184, rating=4.0),
#  Rating(user=31873, product=4628, rating=3.0),
#  Rating(user=81222, product=4577, rating=5.0),
#  Rating(user=7172, product=8057, rating=4.0),
#  Rating(user=63743, product=2047, rating=2.0),
#  Rating(user=45909, product=3568, rating=5.0),
#  Rating(user=7175, product=10115, rating=5.0),
#  Rating(user=42457, product=3046, rating=2.0),
#  Rating(user=3603, product=12661, rating=3.0),
#  Rating(user=56565, product=1082, rating=5.0),
#  Rating(user=3604, product=9638, rating=4.0),
#  Rating(user=74292, product=7665, rating=1.0),
#  Rating(user=160, product=12155, rating=5.0),
#  Rating(user=63753, product=3100, rating=5.0),
#  Rating(user=10740, product=4617, rating=3.0),
#  Rating(user=53059, product=10693, rating=5.0),
#  Rating(user=74295, product=8622, rating=4.0),
#  Rating(user=10666, product=10695, rating=3.0),
#  Rating(user=7187, product=12172, rating=5.0),
#  Rating(user=46042, product=8579, rating=1.0),
#  Rating(user=70806, product=8096, rating=1.0),
#  Rating(user=3470, product=4590, rating=4.0),
#  Rating(user=88239, product=8573, rating=5.0),
#  Rating(user=88372, product=9643, rating=3.0),
#  Rating(user=63772, product=1005, rating=5.0),
#  Rating(user=3622, product=5576, rating=4.0),
#  Rating(user=14241, product=12162, rating=5.0),
#  Rating(user=49468, product=6041, rating=4.0),
#  Rating(user=67318, product=11667, rating=4.0),
#  Rating(user=56593, product=9147, rating=5.0),
#  Rating(user=46055, product=9647, rating=1.0),
#  Rating(user=31724, product=1612, rating=4.0),
#  Rating(user=70822, product=2149, rating=5.0),
#  Rating(user=77763, product=5149, rating=5.0),
#  Rating(user=3635, product=2636, rating=5.0),
#  Rating(user=60220, product=10604, rating=5.0),
#  Rating(user=81253, product=11685, rating=4.0),
#  Rating(user=70831, product=6123, rating=5.0),
#  Rating(user=17784, product=11669, rating=5.0),
#  Rating(user=10777, product=2639, rating=5.0),
#  Rating(user=53091, product=5609, rating=4.0),
#  Rating(user=7215, product=9118, rating=4.0),
#  Rating(user=81263, product=3574, rating=5.0),
#  Rating(user=42495, product=3171, rating=5.0),
#  Rating(user=56612, product=4137, rating=5.0),
#  Rating(user=46072, product=6674, rating=5.0),
#  Rating(user=88390, product=3667, rating=5.0),
#  Rating(user=49650, product=11208, rating=5.0),
#  Rating(user=192, product=4187, rating=1.0),
#  Rating(user=46074, product=2644, rating=4.0),
#  Rating(user=88207, product=1589, rating=3.0),
#  Rating(user=35447, product=5089, rating=4.0),
#  Rating(user=3660, product=5563, rating=5.0),
#  Rating(user=88220, product=6673, rating=4.0),
#  Rating(user=77786, product=8164, rating=2.0),
#  Rating(user=24927, product=6679, rating=3.0),
#  Rating(user=3665, product=10711, rating=1.0),
#  Rating(user=84849, product=9167, rating=3.0),
#  Rating(user=31923, product=1644, rating=1.0),
#  Rating(user=14299, product=3065, rating=2.0),
#  Rating(user=77791, product=6155, rating=4.0),
#  Rating(user=81158, product=12680, rating=4.0),
#  Rating(user=31739, product=9609, rating=4.0),
#  Rating(user=201, product=5055, rating=5.0),
#  Rating(user=67349, product=3628, rating=1.0),
#  Rating(user=77793, product=964, rating=4.0),
#  Rating(user=88402, product=7616, rating=5.0),
#  Rating(user=81284, product=12762, rating=4.5),
#  Rating(user=38957, product=12690, rating=5.0),
#  Rating(user=46086, product=7694, rating=2.0),
#  Rating(user=70851, product=5070, rating=5.0),
#  Rating(user=70853, product=10150, rating=3.0),
#  Rating(user=88404, product=1650, rating=1.0),
#  Rating(user=56633, product=2029, rating=5.0),
#  Rating(user=60048, product=5546, rating=5.0),
#  Rating(user=81292, product=4612, rating=5.0),
#  Rating(user=84898, product=8071, rating=5.0),
#  Rating(user=7098, product=8123, rating=3.0),
#  Rating(user=14316, product=10070, rating=4.0),
#  Rating(user=67357, product=3545, rating=4.0),
#  Rating(user=212, product=87, rating=3.0),
#  Rating(user=81303, product=616, rating=3.0),
#  Rating(user=42526, product=4108, rating=5.0),
#  Rating(user=53129, product=6585, rating=1.0),
#  Rating(user=46098, product=8519, rating=4.0),
#  Rating(user=31940, product=545, rating=4.0),
#  Rating(user=42528, product=10069, rating=4.0),
#  Rating(user=84908, product=4115, rating=5.0),
#  Rating(user=53133, product=11727, rating=5.0),
#  Rating(user=10820, product=5670, rating=5.0),
#  Rating(user=67366, product=3599, rating=5.0),
#  Rating(user=77807, product=9181, rating=3.0),
#  Rating(user=88413, product=6690, rating=3.0),
#  Rating(user=42531, product=10085, rating=5.0),
#  Rating(user=38975, product=5671, rating=5.0),
#  Rating(user=81314, product=6694, rating=5.0),
#  Rating(user=28474, product=8183, rating=4.0),
#  Rating(user=17854, product=5672, rating=5.0),
#  Rating(user=53137, product=12675, rating=3.0),
#  Rating(user=74127, product=2639, rating=4.0),
#  Rating(user=63840, product=3043, rating=3.0),
#  Rating(user=56649, product=10050, rating=4.0),
#  Rating(user=28480, product=12150, rating=1.0),
#  Rating(user=21312, product=3161, rating=5.0),
#  Rating(user=17856, product=2570, rating=4.0),
#  Rating(user=3568, product=11714, rating=4.0),
#  Rating(user=67375, product=3607, rating=4.0),
#  Rating(user=24951, product=8599, rating=5.0),
#  Rating(user=77596, product=3123, rating=5.0),
#  Rating(user=53144, product=10600, rating=4.0),
#  Rating(user=7264, product=1135, rating=4.0),
#  Rating(user=232, product=12254, rating=5.0),
#  Rating(user=56661, product=8031, rating=3.0),
#  Rating(user=84929, product=10142, rating=4.0),
#  Rating(user=10834, product=9686, rating=5.0),
#  Rating(user=17875, product=12672, rating=5.0),
#  Rating(user=7275, product=10069, rating=3.0),
#  Rating(user=35504, product=8188, rating=5.0),
#  Rating(user=35505, product=10199, rating=5.0),
#  Rating(user=81332, product=636, rating=5.0),
#  Rating(user=35508, product=1141, rating=4.0),
#  Rating(user=74382, product=8653, rating=2.0),
#  Rating(user=63857, product=152, rating=3.0),
#  Rating(user=88437, product=9570, rating=1.0),
#  Rating(user=49715, product=1083, rating=4.0),
#  Rating(user=88441, product=11700, rating=4.0),
#  Rating(user=60297, product=11735, rating=4.0),
#  Rating(user=42554, product=11154, rating=2.0),
#  Rating(user=38961, product=11737, rating=4.0),
#  Rating(user=63862, product=6046, rating=4.0),
#  Rating(user=77834, product=4100, rating=2.0),
#  Rating(user=60304, product=7595, rating=4.0),
#  Rating(user=42557, product=8198, rating=5.0),
#  Rating(user=28496, product=9058, rating=3.0),
#  Rating(user=38922, product=4646, rating=4.0),
#  Rating(user=31989, product=12820, rating=3.5),
#  Rating(user=24988, product=8688, rating=5.0),
#  Rating(user=10857, product=7712, rating=1.0),
#  Rating(user=21383, product=6186, rating=1.0),
#  Rating(user=10860, product=10643, rating=5.0),
#  Rating(user=35519, product=11240, rating=1.0),
#  Rating(user=24992, product=3636, rating=5.0),
#  Rating(user=88453, product=2532, rating=1.0),
#  Rating(user=46140, product=9657, rating=5.0),
#  Rating(user=46141, product=3596, rating=5.0),
#  Rating(user=39012, product=4645, rating=2.0),
#  Rating(user=53143, product=6596, rating=5.0),
#  Rating(user=21346, product=4081, rating=3.0),
#  Rating(user=31995, product=2505, rating=3.0),
#  Rating(user=14363, product=8033, rating=5.0),
#  Rating(user=17894, product=8511, rating=2.0),
#  Rating(user=28288, product=2085, rating=3.0),
#  Rating(user=25004, product=1632, rating=1.0),
#  Rating(user=21221, product=11244, rating=4.0),
#  Rating(user=24959, product=5663, rating=4.0),
#  Rating(user=67410, product=4607, rating=5.0),
#  Rating(user=74411, product=7575, rating=5.0),
#  Rating(user=7302, product=10214, rating=5.0),
#  Rating(user=53095, product=12714, rating=5.0),
#  Rating(user=46158, product=4695, rating=1.0),
#  Rating(user=60329, product=4689, rating=5.0),
#  Rating(user=53191, product=8511, rating=4.0),
#  Rating(user=28515, product=4081, rating=5.0),
#  Rating(user=70913, product=1157, rating=1.0),
#  Rating(user=67416, product=8615, rating=5.0),
#  Rating(user=53085, product=10643, rating=4.0),
#  Rating(user=10857, product=3588, rating=2.0),
#  Rating(user=88479, product=5701, rating=1.0),
#  Rating(user=21327, product=4175, rating=2.0),
#  Rating(user=77866, product=8070, rating=5.0),
#  Rating(user=56533, product=4209, rating=5.0),
#  Rating(user=28523, product=11249, rating=5.0),
#  Rating(user=60345, product=4601, rating=2.0),
#  Rating(user=70918, product=3209, rating=4.0),
#  Rating(user=42586, product=2053, rating=3.0),
#  Rating(user=67423, product=8697, rating=5.0),
#  Rating(user=45905, product=2691, rating=4.0),
#  Rating(user=67425, product=3682, rating=5.0),
#  Rating(user=56715, product=9210, rating=5.0),
#  Rating(user=32012, product=4648, rating=5.0),
#  Rating(user=7172, product=87, rating=5.0),
#  Rating(user=46174, product=1534, rating=3.0),
#  Rating(user=17921, product=1634, rating=4.0),
#  Rating(user=88265, product=12832, rating=2.0),
#  Rating(user=17924, product=8585, rating=4.0),
#  Rating(user=67199, product=10710, rating=5.0),
#  Rating(user=81385, product=8507, rating=4.0),
#  Rating(user=25033, product=1695, rating=4.0),
#  Rating(user=60030, product=6725, rating=5.0),
#  Rating(user=77882, product=5212, rating=5.0),
#  Rating(user=3764, product=3639, rating=3.0),
#  Rating(user=35448, product=7211, rating=4.0),
#  Rating(user=70806, product=3216, rating=1.0),
#  Rating(user=35435, product=6071, rating=4.333333333333333),
#  Rating(user=28546, product=5213, rating=1.0),
#  Rating(user=56734, product=8215, rating=3.0),
#  Rating(user=67439, product=11600, rating=4.0),
#  Rating(user=7335, product=1087, rating=5.0),
#  Rating(user=49763, product=11137, rating=3.0),
#  Rating(user=28549, product=8217, rating=3.0),
#  Rating(user=3768, product=9717, rating=5.0),
#  Rating(user=32030, product=2691, rating=4.0),
#  Rating(user=84899, product=10127, rating=4.0),
#  Rating(user=46182, product=7555, rating=3.0),
#  Rating(user=35573, product=19, rating=3.0),
#  Rating(user=70945, product=7131, rating=5.0),
#  Rating(user=14148, product=9056, rating=3.0),
#  Rating(user=17884, product=9719, rating=3.0),
#  Rating(user=38964, product=3626, rating=5.0),
#  Rating(user=70904, product=3072, rating=3.0),
#  Rating(user=28551, product=8220, rating=5.0),
#  Rating(user=53223, product=9720, rating=3.0),
#  Rating(user=56743, product=1141, rating=2.0),
#  Rating(user=88503, product=9601, rating=5.0),
#  Rating(user=85007, product=3225, rating=1.0),
#  Rating(user=49770, product=9076, rating=5.0),
#  Rating(user=46190, product=2702, rating=5.0),
#  Rating(user=39077, product=6658, rating=3.0),
#  Rating(user=56745, product=5077, rating=2.0),
#  Rating(user=32037, product=6559, rating=4.0),
#  Rating(user=88505, product=6606, rating=5.0),
#  Rating(user=88510, product=12670, rating=5.0),
#  Rating(user=56532, product=2208, rating=1.0),
#  Rating(user=38874, product=2707, rating=2.0),
#  Rating(user=24861, product=2524, rating=5.0),
#  Rating(user=85017, product=2133, rating=5.0),
#  Rating(user=17948, product=2708, rating=5.0),
#  Rating(user=77815, product=4228, rating=5.0),
#  Rating(user=77906, product=7226, rating=4.0),
#  Rating(user=81370, product=4551, rating=4.0),
#  Rating(user=21455, product=12173, rating=4.0),
#  Rating(user=25065, product=541, rating=5.0),
#  Rating(user=67464, product=4578, rating=5.0),
#  Rating(user=3532, product=5546, rating=5.0),
#  Rating(user=67471, product=1534, rating=5.0),
#  Rating(user=32052, product=637, rating=4.0),
#  Rating(user=28565, product=105, rating=1.0),
#  Rating(user=337, product=5101, rating=4.0),
#  Rating(user=147, product=7191, rating=5.0),
#  Rating(user=14433, product=3225, rating=4.0),
#  Rating(user=77911, product=6040, rating=4.0),
#  Rating(user=85029, product=12282, rating=1.0),
#  Rating(user=49792, product=964, rating=2.0),
#  Rating(user=14434, product=11113, rating=5.0),
#  Rating(user=35597, product=10225, rating=1.0),
#  Rating(user=53253, product=8711, rating=1.0),
#  Rating(user=63938, product=2218, rating=5.0),
#  Rating(user=39103, product=3681, rating=5.0),
#  Rating(user=56768, product=3221, rating=5.0),
#  Rating(user=46020, product=6547, rating=2.0),
#  Rating(user=42640, product=8079, rating=5.0),
#  Rating(user=56772, product=4100, rating=5.0),
#  Rating(user=53015, product=3692, rating=2.0),
#  Rating(user=17964, product=1518, rating=1.0),
#  Rating(user=56773, product=12137, rating=4.0),
#  Rating(user=81423, product=11649, rating=5.0),
#  Rating(user=10935, product=8523, rating=4.5),
#  Rating(user=3793, product=654, rating=5.0),
#  Rating(user=24812, product=11600, rating=1.0),
#  Rating(user=28573, product=4190, rating=5.0),
#  Rating(user=74187, product=5594, rating=4.0),
#  Rating(user=24879, product=11609, rating=5.0),
#  Rating(user=10947, product=12728, rating=5.0),
#  Rating(user=21486, product=3107, rating=5.0),
#  Rating(user=81411, product=3758, rating=5.0),
#  Rating(user=53245, product=9558, rating=2.5),
#  Rating(user=81439, product=9730, rating=4.0),
#  Rating(user=14454, product=8127, rating=5.0),
#  Rating(user=42404, product=9076, rating=4.0),
#  Rating(user=28586, product=1186, rating=3.0),
#  Rating(user=46235, product=1604, rating=5.0),
#  Rating(user=39122, product=9530, rating=4.0),
#  Rating(user=10957, product=1534, rating=4.0),
#  Rating(user=53277, product=2723, rating=2.0),
#  Rating(user=39124, product=8544, rating=4.0),
#  Rating(user=56788, product=6046, rating=4.0),
#  Rating(user=17684, product=6750, rating=4.0),
#  Rating(user=32084, product=11794, rating=5.0),
#  Rating(user=376, product=2033, rating=5.0),
#  Rating(user=60047, product=8726, rating=4.0),
#  Rating(user=17976, product=9736, rating=3.0),
#  Rating(user=21500, product=6122, rating=1.0),
#  Rating(user=10966, product=8504, rating=4.0),
#  Rating(user=88432, product=9738, rating=3.0),
#  Rating(user=67525, product=5544, rating=1.0),
#  Rating(user=67529, product=9561, rating=4.0),
#  Rating(user=49724, product=6096, rating=2.0),
#  Rating(user=49827, product=3077, rating=4.0),
#  Rating(user=31729, product=2725, rating=4.0),
#  Rating(user=67532, product=6754, rating=1.0),
#  Rating(user=38891, product=11804, rating=5.0),
#  Rating(user=85011, product=3177, rating=2.0),
#  Rating(user=32095, product=8612, rating=5.0),
#  Rating(user=21510, product=7248, rating=3.0),
#  Rating(user=25131, product=2524, rating=3.0),
#  Rating(user=39146, product=2570, rating=1.0),
#  Rating(user=67539, product=7561, rating=4.0),
#  Rating(user=14487, product=3065, rating=5.0),
#  Rating(user=53301, product=6757, rating=1.0),
#  Rating(user=394, product=3066, rating=3.0),
#  Rating(user=60436, product=7630, rating=5.0),
#  Rating(user=28614, product=12325, rating=5.0),
#  Rating(user=85088, product=8036, rating=4.0),
#  Rating(user=3834, product=10632, rating=4.0),
#  Rating(user=63991, product=12120, rating=3.0),
#  Rating(user=3836, product=9745, rating=1.0),
#  Rating(user=25140, product=10584, rating=2.0),
#  Rating(user=56814, product=87, rating=5.0),
#  Rating(user=63993, product=5252, rating=5.0),
#  Rating(user=60447, product=11690, rating=3.0),
#  Rating(user=81364, product=9563, rating=4.0),
#  Rating(user=71030, product=5253, rating=1.0),
#  Rating(user=70659, product=6050, rating=5.0),
#  Rating(user=67407, product=505, rating=5.0),
#  Rating(user=28554, product=8170, rating=4.5),
#  Rating(user=35322, product=9129, rating=5.0),
#  Rating(user=71032, product=12169, rating=5.0),
#  Rating(user=39163, product=6590, rating=4.0),
#  Rating(user=60453, product=5723, rating=5.0),
#  Rating(user=46276, product=2578, rating=5.0),
#  Rating(user=84704, product=10276, rating=1.0),
#  Rating(user=17994, product=6758, rating=2.0),
#  Rating(user=10886, product=6761, rating=5.0),
#  Rating(user=10997, product=3596, rating=1.0),
#  Rating(user=28580, product=8035, rating=4.0),
#  Rating(user=7437, product=8177, rating=5.0),
#  Rating(user=11001, product=4654, rating=3.0),
#  Rating(user=60051, product=4588, rating=4.0),
#  Rating(user=74517, product=6763, rating=4.0),
#  Rating(user=46280, product=12839, rating=1.0),
#  Rating(user=60460, product=3576, rating=4.0),
#  Rating(user=49463, product=10285, rating=3.0),
#  Rating(user=25163, product=3704, rating=1.0),
#  Rating(user=7447, product=1008, rating=5.0),
#  Rating(user=52944, product=9658, rating=5.0),
#  Rating(user=3859, product=12721, rating=1.0),
#  Rating(user=67566, product=6581, rating=2.0),
#  Rating(user=35669, product=9079, rating=4.0),
#  Rating(user=18029, product=10666, rating=4.0),
#  Rating(user=77989, product=9163, rating=2.0),
#  Rating(user=42710, product=8165, rating=5.0),
#  Rating(user=28651, product=19, rating=5.0),
#  Rating(user=81146, product=1600, rating=5.0),
#  Rating(user=56765, product=10053, rating=4.0),
#  Rating(user=64019, product=4220, rating=5.0),
#  Rating(user=52953, product=7760, rating=4.0),
#  Rating(user=46271, product=12833, rating=4.0),
#  Rating(user=60479, product=4569, rating=2.0),
#  Rating(user=78003, product=10111, rating=5.0),
#  Rating(user=21558, product=23, rating=2.0),
#  Rating(user=56838, product=9126, rating=5.0),
#  Rating(user=84969, product=4275, rating=2.0),
#  Rating(user=28658, product=8035, rating=5.0),
#  Rating(user=74545, product=11677, rating=5.0),
#  Rating(user=11023, product=3642, rating=5.0),
#  Rating(user=53342, product=6595, rating=5.0),
#  Rating(user=46299, product=1675, rating=5.0),
#  Rating(user=3804, product=12670, rating=4.0),
#  Rating(user=60484, product=5754, rating=5.0),
#  Rating(user=11025, product=6630, rating=5.0),
#  Rating(user=21564, product=5053, rating=5.0),
#  Rating(user=85125, product=3273, rating=5.0),
#  Rating(user=56844, product=4081, rating=4.0),
#  Rating(user=78011, product=10078, rating=3.0),
#  Rating(user=53143, product=1598, rating=4.0),
#  Rating(user=7463, product=4092, rating=2.0),
#  Rating(user=60486, product=1576, rating=3.0),
#  Rating(user=14520, product=5157, rating=4.0),
#  Rating(user=85134, product=10299, rating=4.0),
#  Rating(user=85136, product=9127, rating=5.0),
#  Rating(user=21571, product=3072, rating=4.0),
#  Rating(user=49883, product=10300, rating=3.0),
#  Rating(user=67584, product=3693, rating=1.0),
#  Rating(user=71068, product=6190, rating=1.0),
#  Rating(user=14343, product=8254, rating=3.0),
#  Rating(user=49441, product=3276, rating=5.0),
#  Rating(user=64034, product=982, rating=1.0),
#  Rating(user=32145, product=11613, rating=2.0),
#  Rating(user=88623, product=10709, rating=3.0),
#  Rating(user=46201, product=2563, rating=3.0),
#  Rating(user=35690, product=6044, rating=5.0),
#  Rating(user=45918, product=10795, rating=3.0),
#  Rating(user=67588, product=4564, rating=4.0),
#  Rating(user=53354, product=10600, rating=5.0),
#  Rating(user=53355, product=6766, rating=5.0),
#  Rating(user=32151, product=3545, rating=5.0),
#  Rating(user=78026, product=12339, rating=5.0),
#  Rating(user=21582, product=9253, rating=1.0),
#  Rating(user=18060, product=3574, rating=1.0),
#  Rating(user=38737, product=3646, rating=3.0),
#  Rating(user=63631, product=27, rating=3.0),
#  Rating(user=17905, product=4642, rating=4.0),
#  Rating(user=7171, product=4092, rating=5.0),
#  Rating(user=53360, product=11631, rating=2.0),
#  Rating(user=78029, product=8054, rating=3.0),
#  Rating(user=81517, product=6547, rating=3.0),
#  Rating(user=60105, product=551, rating=2.0),
#  Rating(user=3534, product=12779, rating=3.0),
#  Rating(user=32158, product=11829, rating=5.0),
#  Rating(user=74563, product=1708, rating=5.0),
#  Rating(user=49617, product=11170, rating=2.0),
#  Rating(user=64044, product=4283, rating=5.0),
#  Rating(user=70907, product=5187, rating=4.0),
#  Rating(user=56869, product=976, rating=5.0),
#  Rating(user=10750, product=5619, rating=4.0),
#  Rating(user=18065, product=4548, rating=3.0),
#  Rating(user=11048, product=4692, rating=5.0),
#  Rating(user=14547, product=4108, rating=4.0),
#  Rating(user=39211, product=8743, rating=5.0),
#  Rating(user=78039, product=9259, rating=2.0),
#  Rating(user=49732, product=7206, rating=1.0),
#  Rating(user=28688, product=11124, rating=5.0),
#  Rating(user=60078, product=530, rating=4.0),
#  Rating(user=67607, product=5544, rating=4.0),
#  Rating(user=88642, product=3682, rating=4.0),
#  Rating(user=78043, product=10174, rating=1.0),
#  Rating(user=85165, product=8117, rating=5.0),
#  Rating(user=85166, product=7185, rating=3.0),
#  Rating(user=7059, product=10118, rating=3.0),
#  Rating(user=21267, product=5178, rating=4.0),
#  Rating(user=28679, product=8057, rating=5.0),
#  Rating(user=17946, product=8767, rating=5.0),
#  Rating(user=71091, product=11206, rating=5.0),
#  Rating(user=17950, product=12837, rating=4.0),
#  Rating(user=28377, product=7104, rating=3.0),
#  Rating(user=7499, product=8267, rating=5.0),
#  Rating(user=60035, product=1553, rating=4.0),
#  Rating(user=46341, product=4764, rating=4.0),
#  Rating(user=53124, product=5567, rating=5.0),
#  Rating(user=74486, product=11839, rating=5.0),
#  Rating(user=81541, product=1608, rating=4.0),
#  Rating(user=77617, product=2026, rating=3.0),
#  Rating(user=11068, product=11841, rating=5.0),
#  Rating(user=64067, product=10313, rating=4.0),
#  Rating(user=71101, product=2156, rating=5.0),
#  Rating(user=49927, product=9134, rating=5.0),
#  Rating(user=67626, product=9747, rating=2.0),
#  Rating(user=3929, product=705, rating=4.0),
#  Rating(user=39229, product=1704, rating=3.0),
#  Rating(user=21352, product=11153, rating=4.0),
#  Rating(user=53389, product=3557, rating=4.0),
#  Rating(user=38737, product=5663, rating=4.0),
#  Rating(user=71104, product=6081, rating=5.0),
#  Rating(user=35733, product=11319, rating=5.0),
#  Rating(user=16, product=10114, rating=4.0),
#  Rating(user=67602, product=10757, rating=5.0),
#  Rating(user=60528, product=7565, rating=1.0),
#  Rating(user=21271, product=4244, rating=5.0),
#  Rating(user=11076, product=4687, rating=3.0),
#  Rating(user=56892, product=5280, rating=5.0),
#  Rating(user=14577, product=2099, rating=4.0),
#  Rating(user=81558, product=11640, rating=5.0),
#  Rating(user=49939, product=3235, rating=1.0),
#  Rating(user=11083, product=6638, rating=2.0),
#  Rating(user=78074, product=10240, rating=5.0),
#  Rating(user=60539, product=2761, rating=1.0),
#  Rating(user=42780, product=5101, rating=5.0),
#  Rating(user=42781, product=12347, rating=1.0),
#  Rating(user=71112, product=1082, rating=4.0),
#  Rating(user=18097, product=9581, rating=5.0),
#  Rating(user=21642, product=9204, rating=5.0),
#  Rating(user=18098, product=6646, rating=5.0),
#  Rating(user=18099, product=7584, rating=3.0),
#  Rating(user=81562, product=10666, rating=1.0),
#  Rating(user=46265, product=7679, rating=2.0),
#  Rating(user=3934, product=3799, rating=5.0),
#  Rating(user=81566, product=10592, rating=5.0),
#  Rating(user=39247, product=2527, rating=5.0),
#  Rating(user=71115, product=6092, rating=5.0),
#  Rating(user=74420, product=1565, rating=4.0),
#  Rating(user=39250, product=3586, rating=1.0),
#  Rating(user=45902, product=10740, rating=5.0),
#  Rating(user=46360, product=12670, rating=5.0),
#  Rating(user=56908, product=4298, rating=1.0),
#  Rating(user=28734, product=85, rating=5.0),
#  Rating(user=67648, product=5539, rating=5.0),
#  Rating(user=31897, product=8601, rating=4.0),
#  Rating(user=31862, product=6637, rating=4.0),
#  Rating(user=14355, product=10194, rating=1.0),
#  Rating(user=18119, product=7747, rating=5.0),
#  Rating(user=64101, product=2269, rating=1.0),
#  Rating(user=81584, product=8507, rating=4.0),
#  Rating(user=502, product=10325, rating=5.0),
#  Rating(user=53270, product=6658, rating=5.0),
#  Rating(user=67664, product=5778, rating=5.0),
#  Rating(user=39261, product=6545, rating=3.0),
#  Rating(user=17733, product=10735, rating=4.0),
#  Rating(user=11099, product=1534, rating=5.0),
#  Rating(user=35683, product=1230, rating=5.0),
#  Rating(user=46378, product=11722, rating=5.0),
#  Rating(user=35760, product=29, rating=3.0),
#  Rating(user=78104, product=970, rating=5.0),
#  Rating(user=31788, product=5780, rating=5.0),
#  Rating(user=88700, product=1680, rating=5.0),
#  Rating(user=60564, product=11602, rating=3.0),
#  Rating(user=53426, product=2527, rating=4.0),
#  Rating(user=507, product=3079, rating=4.0),
#  Rating(user=39271, product=6738, rating=1.0),
#  Rating(user=70659, product=10205, rating=4.0),
#  Rating(user=28753, product=8251, rating=5.0),
#  Rating(user=53265, product=715, rating=4.5),
#  Rating(user=88710, product=10817, rating=4.0),
#  Rating(user=7547, product=12147, rating=2.0),
#  Rating(user=60572, product=10691, rating=5.0),
#  Rating(user=42633, product=4100, rating=3.0),
#  Rating(user=3970, product=3700, rating=4.0),
#  Rating(user=46388, product=5670, rating=1.0),
#  Rating(user=7551, product=992, rating=5.0),
#  Rating(user=46389, product=1515, rating=4.0),
#  Rating(user=74653, product=6758, rating=1.0),
#  Rating(user=71147, product=5032, rating=1.0),
#  Rating(user=25293, product=7553, rating=4.0),
#  Rating(user=14612, product=11197, rating=3.0),
#  Rating(user=347, product=12139, rating=5.0),
#  Rating(user=60583, product=12912, rating=5.0),
#  Rating(user=85233, product=7, rating=4.0),
#  Rating(user=42616, product=6264, rating=3.0),
#  Rating(user=67354, product=8582, rating=4.0),
#  Rating(user=21682, product=8278, rating=2.0),
#  Rating(user=67684, product=3811, rating=5.0),
#  Rating(user=74661, product=2768, rating=5.0),
#  Rating(user=49497, product=11225, rating=5.0),
#  Rating(user=28674, product=3302, rating=5.0),
#  Rating(user=25250, product=4782, rating=4.0),
#  Rating(user=18154, product=8567, rating=4.0),
#  Rating(user=7560, product=7097, rating=4.0),
#  Rating(user=67691, product=9787, rating=1.0),
#  Rating(user=25024, product=1552, rating=5.0),
#  Rating(user=42839, product=8171, rating=1.0),
#  Rating(user=74666, product=1571, rating=2.5),
#  Rating(user=74311, product=6604, rating=5.0),
#  Rating(user=71159, product=12238, rating=5.0),
#  Rating(user=39293, product=12689, rating=3.0),
#  Rating(user=60587, product=1527, rating=5.0),
#  Rating(user=67248, product=8585, rating=5.0),
#  Rating(user=21686, product=3110, rating=4.0),
#  Rating(user=64138, product=2251, rating=2.0),
#  Rating(user=17732, product=6673, rating=4.0),
#  Rating(user=71163, product=10114, rating=4.0),
#  Rating(user=81619, product=7559, rating=5.0),
#  Rating(user=64141, product=5297, rating=5.0),
#  Rating(user=46407, product=3815, rating=5.0),
#  Rating(user=42845, product=8150, rating=5.0),
#  Rating(user=17709, product=481, rating=5.0),
#  Rating(user=7573, product=12119, rating=4.0),
#  Rating(user=28775, product=7285, rating=4.0),
#  Rating(user=39158, product=3816, rating=5.0),
#  Rating(user=67556, product=11754, rating=5.0),
#  Rating(user=35784, product=9104, rating=5.0),
#  Rating(user=81517, product=511, rating=3.0),
#  Rating(user=21145, product=4279, rating=5.0),
#  Rating(user=7578, product=167, rating=5.0),
#  Rating(user=46412, product=2525, rating=4.5),
#  Rating(user=56962, product=6281, rating=1.0),
#  Rating(user=60598, product=10604, rating=4.0),
#  Rating(user=71171, product=3205, rating=4.0),
#  Rating(user=25312, product=12902, rating=5.0),
#  Rating(user=18165, product=9791, rating=1.0),
#  Rating(user=39316, product=1772, rating=4.0),
#  Rating(user=539, product=2282, rating=4.0),
#  Rating(user=3881, product=8585, rating=2.0),
#  Rating(user=14629, product=6039, rating=5.0),
#  Rating(user=39319, product=3640, rating=3.0),
#  Rating(user=60609, product=3681, rating=5.0),
#  Rating(user=3997, product=8791, rating=1.0),
#  Rating(user=53452, product=11809, rating=5.0),
#  Rating(user=46421, product=7553, rating=5.0),
#  Rating(user=71187, product=8031, rating=4.0),
#  Rating(user=543, product=8057, rating=5.0),
#  Rating(user=88525, product=7798, rating=4.0),
#  Rating(user=81637, product=10757, rating=4.0),
#  Rating(user=28790, product=221, rating=2.0),
#  Rating(user=42866, product=43, rating=4.0),
#  Rating(user=11148, product=12692, rating=3.0),
#  Rating(user=56471, product=236, rating=2.0),
#  Rating(user=11149, product=11643, rating=5.0),
#  Rating(user=42867, product=3043, rating=4.0),
#  Rating(user=4008, product=6559, rating=3.0),
#  Rating(user=42868, product=8293, rating=5.0),
#  Rating(user=14647, product=12165, rating=5.0),
#  Rating(user=14648, product=10045, rating=5.0),
#  Rating(user=18181, product=10599, rating=1.0),
#  Rating(user=32281, product=6581, rating=4.0),
#  Rating(user=81643, product=10823, rating=5.0),
#  Rating(user=39069, product=11605, rating=3.0),
#  Rating(user=14649, product=3069, rating=5.0),
#  Rating(user=81645, product=3651, rating=2.0),
#  Rating(user=74693, product=8603, rating=4.0),
#  Rating(user=39335, product=3701, rating=4.0),
#  Rating(user=81647, product=12672, rating=2.0),
#  Rating(user=31745, product=1698, rating=4.0),
#  Rating(user=4011, product=8660, rating=5.0),
#  Rating(user=56538, product=5060, rating=3.0),
#  Rating(user=53288, product=602, rating=5.0),
#  Rating(user=85274, product=5037, rating=2.5),
#  Rating(user=74698, product=2508, rating=1.0),
#  Rating(user=42450, product=11265, rating=1.0),
#  Rating(user=42881, product=6146, rating=4.0),
#  Rating(user=88769, product=2528, rating=1.0),
#  Rating(user=60123, product=8603, rating=3.0),
#  Rating(user=56987, product=12150, rating=5.0),
#  Rating(user=49448, product=3123, rating=4.0),
#  Rating(user=85280, product=9095, rating=2.0),
#  Rating(user=42884, product=3314, rating=5.0),
#  Rating(user=74704, product=2571, rating=5.0),
#  Rating(user=7611, product=10043, rating=1.0),
#  Rating(user=35273, product=5126, rating=2.0),
#  Rating(user=25333, product=11695, rating=4.0),
#  Rating(user=74706, product=10592, rating=4.0),
#  Rating(user=53473, product=3823, rating=1.0),
#  Rating(user=14657, product=196, rating=1.0),
#  Rating(user=81387, product=2734, rating=3.0),
#  Rating(user=39345, product=728, rating=4.0),
#  Rating(user=88777, product=12669, rating=2.0),
#  Rating(user=11174, product=6699, rating=5.0),
#  Rating(user=71212, product=12192, rating=5.0),
#  Rating(user=42897, product=6285, rating=3.0),
#  Rating(user=71214, product=11135, rating=4.5),
#  Rating(user=60643, product=6809, rating=1.0),
#  Rating(user=21296, product=5032, rating=1.0),
#  Rating(user=28804, product=2076, rating=1.0),
#  Rating(user=32297, product=2506, rating=2.0),
#  Rating(user=21748, product=1021, rating=3.0),
#  Rating(user=46445, product=2611, rating=4.0),
#  Rating(user=7625, product=8122, rating=5.0),
#  Rating(user=81408, product=2674, rating=2.5),
#  Rating(user=18199, product=1781, rating=5.0),
#  Rating(user=88788, product=6590, rating=5.0),
#  Rating(user=571, product=6081, rating=2.0),
#  Rating(user=21183, product=5037, rating=5.0),
#  Rating(user=42904, product=2049, rating=4.0),
#  Rating(user=56420, product=11353, rating=2.0),
#  Rating(user=104, product=11355, rating=2.0),
#  Rating(user=71233, product=3227, rating=4.5),
#  Rating(user=39358, product=4569, rating=5.0),
#  Rating(user=71234, product=5050, rating=4.0),
#  Rating(user=64206, product=9170, rating=5.0),
#  Rating(user=35831, product=12366, rating=2.0),
#  Rating(user=7635, product=3319, rating=3.0),
#  Rating(user=78138, product=10116, rating=5.0),
#  Rating(user=7636, product=5046, rating=3.0),
#  Rating(user=21753, product=9074, rating=5.0),
#  Rating(user=46051, product=2602, rating=3.0),
#  Rating(user=74451, product=9548, rating=1.0),
#  Rating(user=53410, product=9560, rating=3.0),
#  Rating(user=53409, product=4543, rating=5.0),
#  Rating(user=25356, product=6717, rating=1.0),
#  Rating(user=60257, product=8621, rating=3.0),
#  Rating(user=14682, product=1004, rating=2.0),
#  Rating(user=7383, product=9286, rating=5.0),
#  Rating(user=7652, product=9287, rating=5.0),
#  Rating(user=53417, product=2674, rating=5.0),
#  Rating(user=7653, product=10121, rating=4.0),
#  Rating(user=67774, product=7562, rating=5.0),
#  Rating(user=18216, product=9811, rating=2.0),
#  Rating(user=32110, product=10644, rating=3.0),
#  Rating(user=71244, product=964, rating=2.0),
#  Rating(user=74737, product=9813, rating=2.0),
#  Rating(user=3615, product=7754, rating=3.0),
#  Rating(user=88810, product=9744, rating=4.0),
#  Rating(user=88811, product=11602, rating=5.0),
#  Rating(user=63603, product=7145, rating=2.0),
#  Rating(user=35853, product=12386, rating=5.0),
#  Rating(user=67779, product=3776, rating=2.0),
#  Rating(user=32330, product=10634, rating=5.0),
#  Rating(user=21220, product=6116, rating=3.0),
#  Rating(user=18228, product=8506, rating=4.0),
#  Rating(user=11213, product=12760, rating=4.0),
#  Rating(user=53505, product=6571, rating=4.0),
#  Rating(user=85322, product=1141, rating=5.0),
#  Rating(user=67784, product=2527, rating=5.0),
#  Rating(user=28832, product=4121, rating=1.0),
#  Rating(user=78112, product=119, rating=5.0),
#  Rating(user=14112, product=8070, rating=4.0),
#  Rating(user=42518, product=21, rating=5.0),
#  Rating(user=18035, product=11747, rating=5.0),
#  Rating(user=57030, product=991, rating=1.0),
#  Rating(user=88824, product=473, rating=4.0),
#  Rating(user=14701, product=2030, rating=2.0),
#  Rating(user=18238, product=6730, rating=4.0),
#  Rating(user=25137, product=6703, rating=5.0),
#  Rating(user=46485, product=11638, rating=5.0),
#  Rating(user=39388, product=6738, rating=2.0),
#  Rating(user=35861, product=19, rating=3.0),
#  Rating(user=67799, product=12951, rating=1.0),
#  Rating(user=88829, product=8511, rating=4.0),
#  Rating(user=25389, product=2528, rating=2.0),
#  Rating(user=35865, product=8309, rating=3.5),
#  Rating(user=81591, product=1725, rating=5.0),
#  Rating(user=78218, product=5324, rating=5.0),
#  Rating(user=17644, product=9583, rating=5.0),
#  Rating(user=28841, product=9112, rating=5.0),
#  Rating(user=88316, product=1795, rating=1.0),
#  Rating(user=67802, product=9548, rating=3.0),
#  Rating(user=11220, product=473, rating=1.0),
#  Rating(user=39393, product=2532, rating=1.0),
#  Rating(user=49626, product=4252, rating=4.0),
#  Rating(user=7670, product=7, rating=5.0),
#  Rating(user=71272, product=93, rating=4.0),
#  Rating(user=25116, product=502, rating=3.0),
#  Rating(user=57038, product=9058, rating=4.0),
#  Rating(user=71274, product=6280, rating=1.0),
#  Rating(user=14715, product=6302, rating=5.0),
#  Rating(user=625, product=10069, rating=4.0),
#  Rating(user=39013, product=9725, rating=5.0),
#  Rating(user=67181, product=3848, rating=4.0),
#  Rating(user=11142, product=12876, rating=4.0),
#  Rating(user=42763, product=7119, rating=5.0),
#  Rating(user=64249, product=9296, rating=5.0),
#  Rating(user=88840, product=7743, rating=4.0),
#  Rating(user=7687, product=5134, rating=1.0),
#  Rating(user=21165, product=6063, rating=4.0),
#  Rating(user=85348, product=2031, rating=3.0),
#  Rating(user=4089, product=1561, rating=5.0),
#  Rating(user=99, product=2300, rating=5.0),
#  Rating(user=35669, product=3060, rating=5.0),
#  Rating(user=85352, product=2087, rating=4.0),
#  Rating(user=46510, product=1612, rating=5.0),
#  Rating(user=21799, product=257, rating=1.0),
#  Rating(user=14612, product=10204, rating=3.5),
#  Rating(user=3615, product=11754, rating=5.0),
#  Rating(user=70675, product=8058, rating=4.0),
#  Rating(user=3589, product=1597, rating=4.0),
#  Rating(user=74596, product=3610, rating=5.0),
#  Rating(user=39416, product=4576, rating=3.0),
#  Rating(user=14735, product=10195, rating=4.0),
#  Rating(user=14737, product=2030, rating=5.0),
#  Rating(user=35887, product=1190, rating=5.0),
#  Rating(user=88589, product=12954, rating=2.0),
#  Rating(user=53182, product=535, rating=4.0),
#  Rating(user=39418, product=479, rating=4.0),
#  Rating(user=32014, product=488, rating=5.0),
#  Rating(user=60398, product=7607, rating=5.0),
#  Rating(user=32367, product=11700, rating=3.0),
#  Rating(user=64265, product=9277, rating=5.0),
#  Rating(user=4104, product=3636, rating=5.0),
#  Rating(user=88250, product=9540, rating=4.0),
#  Rating(user=85363, product=206, rating=5.0),
#  Rating(user=7636, product=19, rating=2.0),
#  Rating(user=7328, product=92, rating=2.0),
#  Rating(user=21816, product=11108, rating=3.0),
#  Rating(user=4107, product=3740, rating=5.0),
#  Rating(user=645, product=11110, rating=4.0),
#  Rating(user=42969, product=964, rating=2.0),
#  Rating(user=81739, product=1801, rating=4.0),
#  Rating(user=57060, product=10345, rating=1.0),
#  Rating(user=67836, product=3618, rating=5.0),
#  Rating(user=25418, product=5716, rating=1.0),
#  Rating(user=655, product=241, rating=3.0),
#  Rating(user=14755, product=12185, rating=1.0),
#  Rating(user=11052, product=4673, rating=3.0),
#  Rating(user=60057, product=9648, rating=4.0),
#  Rating(user=24903, product=480, rating=2.0),
#  Rating(user=28443, product=1010, rating=2.0),
#  Rating(user=4116, product=11600, rating=1.0),
#  Rating(user=88867, product=6587, rating=5.0),
#  Rating(user=46538, product=1565, rating=5.0),
#  Rating(user=49615, product=12119, rating=3.0),
#  Rating(user=17667, product=10677, rating=3.0),
#  Rating(user=18289, product=573, rating=5.0),
#  Rating(user=28882, product=976, rating=5.0),
#  Rating(user=4119, product=3854, rating=2.0),
#  Rating(user=60731, product=9648, rating=5.0),
#  Rating(user=4122, product=6605, rating=2.0),
#  Rating(user=74784, product=4820, rating=5.0),
#  Rating(user=4123, product=9548, rating=3.0),
#  Rating(user=67848, product=7695, rating=2.0),
#  Rating(user=21836, product=12157, rating=4.0),
#  Rating(user=32391, product=6547, rating=5.0),
#  Rating(user=21839, product=2192, rating=4.0),
#  Rating(user=81258, product=9571, rating=3.0),
#  Rating(user=35445, product=11115, rating=3.0),
#  Rating(user=24926, product=5633, rating=3.0),
#  Rating(user=46077, product=2672, rating=5.0),
#  Rating(user=46548, product=10666, rating=3.0),
#  Rating(user=360, product=1008, rating=4.0),
#  Rating(user=78001, product=11368, rating=5.0),
#  Rating(user=25440, product=3607, rating=5.0),
#  Rating(user=67860, product=7768, rating=5.0),
#  Rating(user=7734, product=2046, rating=4.0),
#  Rating(user=50108, product=4341, rating=1.0),
#  Rating(user=11266, product=7550, rating=5.0),
#  Rating(user=60088, product=10592, rating=2.0),
#  Rating(user=35665, product=10200, rating=4.0),
#  Rating(user=60750, product=9561, rating=5.0),
#  Rating(user=17765, product=3568, rating=5.0),
#  Rating(user=49835, product=4196, rating=5.0),
#  Rating(user=28908, product=19, rating=5.0),
#  Rating(user=28650, product=7272, rating=3.0),
#  Rating(user=21857, product=1280, rating=4.0),
#  Rating(user=46127, product=758, rating=2.0),
#  Rating(user=39454, product=9563, rating=5.0),
#  Rating(user=85388, product=8057, rating=1.0),
#  Rating(user=39459, product=8825, rating=5.0),
#  Rating(user=77869, product=10207, rating=5.0),
#  Rating(user=43010, product=3281, rating=1.0),
#  Rating(user=17692, product=8801, rating=4.0),
#  Rating(user=18316, product=12672, rating=4.0),
#  Rating(user=18206, product=6579, rating=5.0),
#  Rating(user=24760, product=5643, rating=3.0),
#  Rating(user=42854, product=27, rating=5.0),
#  Rating(user=46570, product=2527, rating=5.0),
#  Rating(user=11275, product=752, rating=5.0),
#  Rating(user=43018, product=3196, rating=4.0),
#  Rating(user=43019, product=10203, rating=5.0),
#  Rating(user=35948, product=11121, rating=3.0),
#  Rating(user=88550, product=2524, rating=4.0),
#  Rating(user=14711, product=2099, rating=5.0),
#  Rating(user=74805, product=3764, rating=2.0),
#  Rating(user=60122, product=3638, rating=4.0),
#  Rating(user=21240, product=10260, rating=3.0),
#  Rating(user=50130, product=12161, rating=4.0),
#  Rating(user=43026, product=3061, rating=5.0),
#  Rating(user=78297, product=5289, rating=2.0),
#  Rating(user=31851, product=8511, rating=3.5),
#  Rating(user=11288, product=6611, rating=5.0),
#  Rating(user=64295, product=8115, rating=5.0),
#  Rating(user=21872, product=10345, rating=1.0),
#  Rating(user=81790, product=6559, rating=4.0),
#  Rating(user=67510, product=9528, rating=5.0),
#  Rating(user=17653, product=4588, rating=3.0),
#  Rating(user=25473, product=2544, rating=5.0),
#  Rating(user=88913, product=9585, rating=5.0),
#  Rating(user=60507, product=3638, rating=4.0),
#  Rating(user=67887, product=2529, rating=2.0),
#  Rating(user=43038, product=8095, rating=2.0),
#  Rating(user=4171, product=6595, rating=3.0),
#  Rating(user=71359, product=12415, rating=5.0),
#  Rating(user=43005, product=12416, rating=5.0),
#  Rating(user=64182, product=9065, rating=5.0),
#  Rating(user=64335, product=6136, rating=4.0),
#  Rating(user=32440, product=481, rating=5.0),
#  Rating(user=81241, product=3864, rating=1.0),
#  Rating(user=49671, product=3039, rating=5.0),
#  Rating(user=77665, product=7145, rating=3.0),
#  Rating(user=18339, product=8557, rating=4.0),
#  ...]

# %%
sc.setCheckpointDir(checkpoint_file)
ALS.checkpointInterval = 2

# %%
modelRDD = ALS.train(ratings=stars_data, rank=1, iterations=70, lambda_=0.01, nonnegative=True)

# %%
def collectAlsModel(modelRDD, u_table, b_table):
    user_featrue = modelRDD.userFeatures() \
        .map(lambda x: (u_table[x[0]], list(x[1])[0])) \
        .collectAsMap()
    product_feature = modelRDD.productFeatures() \
        .map(lambda x: (b_table[x[0]], list(x[1])[0])) \
        .collectAsMap()
    return [user_featrue, product_feature]

# %%
def saveAlsModel(modelRDD, u_table, b_table, model_file):
    model = collectAlsModel(modelRDD, u_table, b_table)
    with open(model_file, 'w', encoding='utf-8') as fp:
        json.dump(model, fp)

# %%
saveAlsModel(modelRDD, u_table, b_table, model_file)

# %%
# def convertToNum(x, u_table, b_table):
#     # x - (uid, bid)
#     uid = x[0]
#     bid = x[1]
#     try:
#         n_uid = u_table.index(uid)
#         n_bid = b_table.index(bid)
#     except ValueError as e:
#         return (uid, None)
#     return (n_uid, n_bid)

# %%
# raw_testing = sc.textFile(test_file) \
#     .map(json.loads) \
#     .map(lambda r: (r['user_id'], r['business_id'])) \
#     .persist(StorageLevel.MEMORY_AND_DISK)

# testing_with_none = raw_testing.map(lambda x: convertToNum(x, u_table, b_table)).persist(StorageLevel.MEMORY_AND_DISK)
# testing_without_none = testing_with_none.filter(lambda x: type(x[0]) != str)
# testing_none = testing_with_none.filter(lambda x: type(x[0]) == str) \
#     .map(lambda x: (x, None)) \
#     .collect()

# %%
# test_pre_all = modelRDD.predictAll(testing_without_none).persist(StorageLevel.MEMORY_AND_DISK)

# %%
# test_pre = test_pre_all.map(lambda x: ((u_table[x[0]], b_table[x[1]]), x[2])).collect()

# %%
# res_dict = {}
# for x in test_pre:
#     res_dict[x[0]] = x[1]
# for x in testing_none:
#     res_dict[x[0]] = x[1]
# # res_dict - {(uid, bid): stars, ...}

# %%
# res_dict = {}
# for x in test_pre:
#     v = x[1]
#     if v > 5.0:
#         v = 5.0
#     res_dict[x[0]] = v
# for x in testing_none:
#     res_dict[x[0]] = x[1]
# # res_dict - {(uid, bid): stars, ...}

# %%
# prediction = raw_testing.map(lambda x: (x, res_dict[x])).collect()

# %%
# def outputResultToFileItembased(prediction):
#     with open(output_file, 'w', encoding='utf-8') as fp:
#         for item in prediction:
#             t = {
#                 'user_id': item[0][0],
#                 'business_id': item[0][1],
#                 'stars': item[1]
#             }
#             fp.write(json.dumps(t))
#             fp.write('\n')

# %%
# # output prediction to file
# outputResultToFileItembased(prediction)
